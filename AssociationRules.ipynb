# %% [markdown]
# <div dir=rtl >
# <h1>قوانین انجمنی</h1>
#
# قوانین انجمنی روابط و وابستگی‌های متقابل بین مجموعه بزرگی از اقلام داده‌ای را نشان می‌دهند.
#
# مثال متداول در رابطه با کشف قوانین انجمنی "تحلیل سبد خرید" است.  در این فرایند با توجه به اقلام مختلفی که مشتریان در سبد خریدشان قرار می‌دهند، عادات و رفتار خرید مشتریان مورد تحلیل قرار می‌گیرد و می‌توان با شناسایی ارتباط بین محصولات، الگوهای تکرار شونده در حین خرید را بدست آورد.
#
# سه پارامتر مهم:
# - Support  میزان محبوبیت یک مجموعه آیتم را با توجه به دفعات حضور در تراکنش‌ها نشان می‌دهد.
# - Confidence  احتمال خرید آیتم y در صورت خرید آیتم x را نشان می‌دهد. x -> y
# - Lift   ترکیب دو پارامتر بالا می‌باشد.
#
# برای پیاده سازی قوانین انجمنی در این تمرین، از الگوریتم Apriori که یکی از محبوب‌ترین و کارآمدترین الگوریتم‌های این حوزه است استفاده می‌کنیم.
#
#
# <font color='Green'> پرسش:  تاثیر مقادیر مختلف پارامتر Lift را در احتمال وقوع نتیجه بررسی کنید.  </font>
# <h1>پاسخ</h1>
#
# <p style="text-align:left;direction:ltr" color='Black'>
# The lift value of a rule is defined like this:<br/>
# lift = confidence / expected_confidence = <br/>
# confidence / ( s(body) * s(head) / s(body) ) = confidence / s(head)<br/>
# Where:<br/>
# s(body)<br/>
# Is the support of the rule body<br/>
# s(head)<br/>
# Is the support of the rule head<br/>  </p>
# <p style="text-align:left;direction:ltr" color='Green'>The lift is a value between 0 and infinity:<br/>
# A lift value greater than 1 indicates that the rule body and the rule head appear more often together than expected, this means that the occurrence of the rule body has a positive effect on the occurrence of the rule head.<br/>
# A lift smaller than 1 indicates that the rule body and the rule head appear less often together than expected, this means that the occurrence of the rule body has a negative effect on the occurrence of the rule head.<br/>
# A lift value near 1 indicates that the rule body and the rule head appear almost as often together as expected, this means that the occurrence of the rule body has almost no effect on the occurrence of the rule head.<br/>
# </p>
#
# </div>

# %% [markdown]
# <div dir=rtl >
# <h1>الگوریتم Apriori</h1>
#
# روش کار الگوریتم به این صورت است که یک  حداقل مقدار پشتیبانی در نظر گرفته    می‌شود و تکرارها با مجموعه آیتم‌های مکرر اتفاق می‌افتند. در صورتیکه  مجموعه‌ها و زیرمجموعه‌ها مقدار پشتیبانی کمتر از حد آستانه داشته باشند حذف می‌شوند. این روند تا زمانیکه امکان حذف وجود نداشته باشد ادامه می‌یابد.
#
# در این بخش از تمرین می‌خواهیم الگوریتم apriori را بر روی مجموعه داده Hypermarket_dataset که شامل سفارشات خرید افراد از فروشگاه های مواد غذایی است اعمال کنیم.
#
#
# </div>

# %% [markdown]
# <div dir=rtl >
# <h1>آماده‌سازی داده</h1>
#
# <font color='Green'>پرسش: برای شروع کار باید داده‌های دیتاست را در قالب ماتریس پراکنده که محصولات  خریداری شده در ستون‌ و شماره سفارشات خرید به عنوان شاخص (index) هستند آماده کنید.
#
#
# برای راحتی کار محصولات خریداری شده در هر سفارش را با اعداد 0,1 کدگذاری کنید.
#
#  نمونه ماتریس خروجی شما:
#
# <img src="https://drive.google.com/uc?id=1eD0jan1ZbeYqSklgK--ks7oeY-MyTA3p"></img>
#
# </div>

# %%
# !pip3 install mlxtend
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
 
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.9/site-packages (0.20.0)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.9/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.9/site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from mlxtend) (60.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.9/site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/site-packages (from mlxtend) (1.19.5)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.9/site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (4.32.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (9.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.15.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# your code here
df = pd.read_csv("data/Hypermarket_dataset.csv")
rows = []
for member in df.groupby(by=["Member_number"]):
    rows.append([[member[0]], *[(item in list(member[1]["itemDescription"])) for item in df["itemDescription"].unique()]]) 
confusion_matrix = pd.DataFrame(rows, columns=[*["order"], *df["itemDescription"].unique()]).set_index("order")
confusion_matrix
# Out:
#         tropical fruit  whole milk  pip fruit  other vegetables  rolls/buns  \
# order
# [1000]           False        True      False             False       False
# [1001]           False        True      False             False        True
# [1002]            True        True      False              True       False
# [1003]           False       False      False             False        True
# [1004]            True        True       True              True        True
# ...                ...         ...        ...               ...         ...
# [4996]            True       False      False             False        True
# [4997]            True        True      False             False       False
# [4998]           False       False      False             False        True
# [4999]            True       False      False              True       False
# [5000]           False       False      False              True       False
#
#         pot plants  citrus fruit   beef  frankfurter  chicken  ...  \
# order                                                          ...
# [1000]       False         False  False        False    False  ...
# [1001]       False         False   True         True    False  ...
# [1002]       False         False  False        False    False  ...
# [1003]       False         False  False        False    False  ...
# [1004]       False         False  False        False    False  ...
# ...            ...           ...    ...          ...      ...  ...
# [4996]       False         False  False        False    False  ...
# [4997]       False         False  False        False    False  ...
# [4998]       False         False  False        False    False  ...
# [4999]       False         False  False        False    False  ...
# [5000]       False         False  False        False    False  ...
#
#         flower (seeds)   rice    tea  salad dressing  specialty vegetables  \
# order
# [1000]           False  False  False           False                 False
# [1001]           False  False  False           False                 False
# [1002]           False  False  False           False                 False
# [1003]           False  False  False           False                 False
# [1004]           False  False  False           False                 False
# ...                ...    ...    ...             ...                   ...
# [4996]           False  False  False           False                 False
# [4997]           False  False  False           False                 False
# [4998]           False  False  False           False                 False
# [4999]           False  False  False           False                 False
# [5000]           False  False  False           False                 False
#
#         pudding powder  ready soups  make up remover  toilet cleaner  \
# order
# [1000]           False        False            False           False
# [1001]           False        False            False           False
# [1002]           False        False            False           False
# [1003]           False        False            False           False
# [1004]           False        False            False           False
# ...                ...          ...              ...             ...
# [4996]           False        False            False           False
# [4997]           False        False            False           False
# [4998]           False        False            False           False
# [4999]           False        False            False           False
# [5000]           False        False            False           False
#
#         preservation products
# order
# [1000]                  False
# [1001]                  False
# [1002]                  False
# [1003]                  False
# [1004]                  False
# ...                       ...
# [4996]                  False
# [4997]                  False
# [4998]                  False
# [4999]                  False
# [5000]                  False
#
# [3898 rows x 167 columns]

# %% [markdown]
# <div dir=rtl >
# <h1>شناسایی الگوهای پر تکرار</h1>
#
# <font color='Green'> پرسش:  با اعمال الگوریتم apriori و به ازای مقدار min_support = 0.07 تمامی الگوهای پر تکرار را تولید نمایید.
#
# </div>

# %%
# your code here
freq_items = apriori(matrix, min_support=0.07, use_colnames=True ,verbose = 1)
freq_items
# Out:
# Processing 4 combinations | Sampling itemset size 4
#      support                                    itemsets
# 0   0.233710                            (tropical fruit)
# 1   0.458184                                (whole milk)
# 2   0.170600                                 (pip fruit)
# 3   0.376603                          (other vegetables)
# 4   0.349666                                (rolls/buns)
# ..       ...                                         ...
# 78  0.097486                              (soda, yogurt)
# 79  0.077219                             (sausage, soda)
# 80  0.081324                     (root vegetables, soda)
# 81  0.082093  (whole milk, other vegetables, rolls/buns)
# 82  0.071832      (whole milk, other vegetables, yogurt)
#
# [83 rows x 2 columns]

# %% [markdown]
# <div dir=rtl >
# <h1>استخراج قوانین انجمنی</h1>
#
#
# <font color='Green'> پرسش: تابعی بنویسید که با گرفتن دو ورودی confidence و lift قوانین انجمنی حاصل را در خروجی نشان دهد. </br>
# برای دو حالت خروجی خود را در گزارش ثبت کنید.
#
#
# </div>

# %%
df_res = association_rules(frequents, metric="confidence", min_threshold=0.3)
df_res[df_res['lift'] >= 0.4]
# Out:
#                        antecedents         consequents  antecedent support  \
# 0                 (tropical fruit)        (whole milk)            0.233710
# 1                 (tropical fruit)  (other vegetables)            0.233710
# 2                 (tropical fruit)        (rolls/buns)            0.233710
# 3                 (tropical fruit)            (yogurt)            0.233710
# 4                 (tropical fruit)              (soda)            0.233710
# 5                      (pip fruit)        (whole milk)            0.170600
# 6                     (whole milk)  (other vegetables)            0.458184
# 7               (other vegetables)        (whole milk)            0.376603
# 8                     (whole milk)        (rolls/buns)            0.458184
# 9                     (rolls/buns)        (whole milk)            0.349666
# 10                  (citrus fruit)        (whole milk)            0.185480
# 11                 (bottled water)        (whole milk)            0.213699
# 12                    (whole milk)            (yogurt)            0.458184
# 13                        (yogurt)        (whole milk)            0.282966
# 14                       (sausage)        (whole milk)            0.206003
# 15               (root vegetables)        (whole milk)            0.230631
# 16                        (pastry)        (whole milk)            0.177527
# 17                   (canned beer)        (whole milk)            0.165213
# 18                    (whole milk)              (soda)            0.458184
# 19                          (soda)        (whole milk)            0.313494
# 20                    (newspapers)        (whole milk)            0.139815
# 21                  (bottled beer)        (whole milk)            0.158799
# 22                 (domestic eggs)        (whole milk)            0.133145
# 23                 (shopping bags)        (whole milk)            0.168291
# 24            (whipped/sour cream)        (whole milk)            0.154695
# 25                     (pip fruit)  (other vegetables)            0.170600
# 26              (other vegetables)        (rolls/buns)            0.376603
# 27                    (rolls/buns)  (other vegetables)            0.349666
# 28                  (citrus fruit)  (other vegetables)            0.185480
# 29                 (bottled water)  (other vegetables)            0.213699
# 30              (other vegetables)            (yogurt)            0.376603
# 31                        (yogurt)  (other vegetables)            0.282966
# 32                       (sausage)  (other vegetables)            0.206003
# 33               (root vegetables)  (other vegetables)            0.230631
# 34                        (pastry)  (other vegetables)            0.177527
# 35              (other vegetables)              (soda)            0.376603
# 36                          (soda)  (other vegetables)            0.313494
# 37                 (shopping bags)  (other vegetables)            0.168291
# 38                  (citrus fruit)        (rolls/buns)            0.185480
# 39                 (bottled water)        (rolls/buns)            0.213699
# 40                    (rolls/buns)            (yogurt)            0.349666
# 41                        (yogurt)        (rolls/buns)            0.282966
# 42                       (sausage)        (rolls/buns)            0.206003
# 43               (root vegetables)        (rolls/buns)            0.230631
# 44                    (rolls/buns)              (soda)            0.349666
# 45                          (soda)        (rolls/buns)            0.313494
# 46                 (bottled water)              (soda)            0.213699
# 47                       (sausage)            (yogurt)            0.206003
# 48               (root vegetables)            (yogurt)            0.230631
# 49                          (soda)            (yogurt)            0.313494
# 50                        (yogurt)              (soda)            0.282966
# 51                       (sausage)              (soda)            0.206003
# 52               (root vegetables)              (soda)            0.230631
# 53  (whole milk, other vegetables)        (rolls/buns)            0.191380
# 54        (whole milk, rolls/buns)  (other vegetables)            0.178553
# 55  (other vegetables, rolls/buns)        (whole milk)            0.146742
# 56  (whole milk, other vegetables)            (yogurt)            0.191380
# 57            (whole milk, yogurt)  (other vegetables)            0.150590
# 58      (other vegetables, yogurt)        (whole milk)            0.120318
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.458184  0.116470    0.498353  1.087672  0.009388    1.080076
# 1             0.376603  0.091329    0.390779  1.037642  0.003313    1.023269
# 2             0.349666  0.088250    0.377607  1.079906  0.006530    1.044892
# 3             0.282966  0.075680    0.323820  1.144379  0.009548    1.060419
# 4             0.313494  0.081837    0.350165  1.116974  0.008570    1.056431
# 5             0.458184  0.086968    0.509774  1.112598  0.008801    1.105239
# 6             0.376603  0.191380    0.417693  1.109106  0.018827    1.070564
# 7             0.458184  0.191380    0.508174  1.109106  0.018827    1.101643
# 8             0.349666  0.178553    0.389698  1.114484  0.018342    1.065592
# 9             0.458184  0.178553    0.510638  1.114484  0.018342    1.107190
# 10            0.458184  0.092355    0.497925  1.086737  0.007371    1.079155
# 11            0.458184  0.112365    0.525810  1.147597  0.014452    1.142615
# 12            0.282966  0.150590    0.328667  1.161510  0.020940    1.068076
# 13            0.458184  0.150590    0.532185  1.161510  0.020940    1.158185
# 14            0.458184  0.106978    0.519303  1.133394  0.012591    1.127146
# 15            0.458184  0.113135    0.490545  1.070630  0.007464    1.063522
# 16            0.458184  0.091072    0.513006  1.119651  0.009732    1.112572
# 17            0.458184  0.087224    0.527950  1.152268  0.011526    1.147795
# 18            0.313494  0.151103    0.329787  1.051973  0.007465    1.024310
# 19            0.458184  0.151103    0.481997  1.051973  0.007465    1.045971
# 20            0.458184  0.072345    0.517431  1.129310  0.008284    1.122775
# 21            0.458184  0.085428    0.537964  1.174124  0.012669    1.172672
# 22            0.458184  0.070292    0.527938  1.152242  0.009287    1.147766
# 23            0.458184  0.091329    0.542683  1.184422  0.014220    1.184772
# 24            0.458184  0.079785    0.515755  1.125650  0.008906    1.118888
# 25            0.376603  0.072345    0.424060  1.126013  0.008096    1.082399
# 26            0.349666  0.146742    0.389646  1.114335  0.015056    1.065502
# 27            0.376603  0.146742    0.419663  1.114335  0.015056    1.074197
# 28            0.376603  0.077476    0.417704  1.109135  0.007623    1.070584
# 29            0.376603  0.093894    0.439376  1.166680  0.013414    1.111969
# 30            0.282966  0.120318    0.319482  1.129050  0.013752    1.053660
# 31            0.376603  0.120318    0.425204  1.129050  0.013752    1.084553
# 32            0.376603  0.092868    0.450809  1.197040  0.015287    1.135119
# 33            0.376603  0.094151    0.408231  1.083982  0.007294    1.053447
# 34            0.376603  0.071575    0.403179  1.070567  0.004718    1.044529
# 35            0.313494  0.124166    0.329700  1.051695  0.006103    1.024178
# 36            0.376603  0.124166    0.396072  1.051695  0.006103    1.032237
# 37            0.376603  0.073114    0.434451  1.153604  0.009735    1.102286
# 38            0.349666  0.071832    0.387275  1.107556  0.006976    1.061380
# 39            0.349666  0.079271    0.370948  1.060863  0.004548    1.033832
# 40            0.282966  0.111339    0.318415  1.125279  0.012396    1.052011
# 41            0.349666  0.111339    0.393472  1.125279  0.012396    1.072224
# 42            0.349666  0.082350    0.399751  1.143235  0.010318    1.083439
# 43            0.349666  0.090816    0.393771  1.126133  0.010172    1.072752
# 44            0.313494  0.119805    0.342627  1.092928  0.010187    1.044316
# 45            0.349666  0.119805    0.382160  1.092928  0.010187    1.052593
# 46            0.313494  0.076193    0.356543  1.137318  0.009199    1.066902
# 47            0.282966  0.075423    0.366127  1.293892  0.017132    1.131196
# 48            0.282966  0.071575    0.310345  1.096758  0.006314    1.039700
# 49            0.282966  0.097486    0.310966  1.098952  0.008778    1.040637
# 50            0.313494  0.097486    0.344515  1.098952  0.008778    1.047325
# 51            0.313494  0.077219    0.374844  1.195698  0.012638    1.098136
# 52            0.313494  0.081324    0.352614  1.124787  0.009022    1.060427
# 53            0.349666  0.082093    0.428954  1.226753  0.015174    1.138847
# 54            0.376603  0.082093    0.459770  1.220834  0.014850    1.153947
# 55            0.458184  0.082093    0.559441  1.220996  0.014859    1.229837
# 56            0.282966  0.071832    0.375335  1.326434  0.017678    1.147870
# 57            0.376603  0.071832    0.477002  1.266589  0.015119    1.191967
# 58            0.458184  0.071832    0.597015  1.303003  0.016704    1.344507

# %%
# your code here
df_res = association_rules(frequents, metric="lift", min_threshold=1)
df_res[df_res['confidence'] >= 0.4]
# Out:
#                        antecedents         consequents  antecedent support  \
# 1                 (tropical fruit)        (whole milk)            0.233710
# 11                     (pip fruit)        (whole milk)            0.170600
# 12                    (whole milk)  (other vegetables)            0.458184
# 13              (other vegetables)        (whole milk)            0.376603
# 15                    (rolls/buns)        (whole milk)            0.349666
# 17                  (citrus fruit)        (whole milk)            0.185480
# 19                 (bottled water)        (whole milk)            0.213699
# 21                        (yogurt)        (whole milk)            0.282966
# 23                       (sausage)        (whole milk)            0.206003
# 25               (root vegetables)        (whole milk)            0.230631
# 27                        (pastry)        (whole milk)            0.177527
# 29                   (canned beer)        (whole milk)            0.165213
# 31                          (soda)        (whole milk)            0.313494
# 33                    (newspapers)        (whole milk)            0.139815
# 35                  (bottled beer)        (whole milk)            0.158799
# 37                 (domestic eggs)        (whole milk)            0.133145
# 39                 (shopping bags)        (whole milk)            0.168291
# 41            (whipped/sour cream)        (whole milk)            0.154695
# 43                     (pip fruit)  (other vegetables)            0.170600
# 45                    (rolls/buns)  (other vegetables)            0.349666
# 47                  (citrus fruit)  (other vegetables)            0.185480
# 49                 (bottled water)  (other vegetables)            0.213699
# 51                        (yogurt)  (other vegetables)            0.282966
# 53                       (sausage)  (other vegetables)            0.206003
# 55               (root vegetables)  (other vegetables)            0.230631
# 57                        (pastry)  (other vegetables)            0.177527
# 61                 (shopping bags)  (other vegetables)            0.168291
# 86  (whole milk, other vegetables)        (rolls/buns)            0.191380
# 87        (whole milk, rolls/buns)  (other vegetables)            0.178553
# 88  (other vegetables, rolls/buns)        (whole milk)            0.146742
# 93            (whole milk, yogurt)  (other vegetables)            0.150590
# 94      (other vegetables, yogurt)        (whole milk)            0.120318
#
#     consequent support   support  confidence      lift  leverage  conviction
# 1             0.458184  0.116470    0.498353  1.087672  0.009388    1.080076
# 11            0.458184  0.086968    0.509774  1.112598  0.008801    1.105239
# 12            0.376603  0.191380    0.417693  1.109106  0.018827    1.070564
# 13            0.458184  0.191380    0.508174  1.109106  0.018827    1.101643
# 15            0.458184  0.178553    0.510638  1.114484  0.018342    1.107190
# 17            0.458184  0.092355    0.497925  1.086737  0.007371    1.079155
# 19            0.458184  0.112365    0.525810  1.147597  0.014452    1.142615
# 21            0.458184  0.150590    0.532185  1.161510  0.020940    1.158185
# 23            0.458184  0.106978    0.519303  1.133394  0.012591    1.127146
# 25            0.458184  0.113135    0.490545  1.070630  0.007464    1.063522
# 27            0.458184  0.091072    0.513006  1.119651  0.009732    1.112572
# 29            0.458184  0.087224    0.527950  1.152268  0.011526    1.147795
# 31            0.458184  0.151103    0.481997  1.051973  0.007465    1.045971
# 33            0.458184  0.072345    0.517431  1.129310  0.008284    1.122775
# 35            0.458184  0.085428    0.537964  1.174124  0.012669    1.172672
# 37            0.458184  0.070292    0.527938  1.152242  0.009287    1.147766
# 39            0.458184  0.091329    0.542683  1.184422  0.014220    1.184772
# 41            0.458184  0.079785    0.515755  1.125650  0.008906    1.118888
# 43            0.376603  0.072345    0.424060  1.126013  0.008096    1.082399
# 45            0.376603  0.146742    0.419663  1.114335  0.015056    1.074197
# 47            0.376603  0.077476    0.417704  1.109135  0.007623    1.070584
# 49            0.376603  0.093894    0.439376  1.166680  0.013414    1.111969
# 51            0.376603  0.120318    0.425204  1.129050  0.013752    1.084553
# 53            0.376603  0.092868    0.450809  1.197040  0.015287    1.135119
# 55            0.376603  0.094151    0.408231  1.083982  0.007294    1.053447
# 57            0.376603  0.071575    0.403179  1.070567  0.004718    1.044529
# 61            0.376603  0.073114    0.434451  1.153604  0.009735    1.102286
# 86            0.349666  0.082093    0.428954  1.226753  0.015174    1.138847
# 87            0.376603  0.082093    0.459770  1.220834  0.014850    1.153947
# 88            0.458184  0.082093    0.559441  1.220996  0.014859    1.229837
# 93            0.376603  0.071832    0.477002  1.266589  0.015119    1.191967
# 94            0.458184  0.071832    0.597015  1.303003  0.016704    1.344507
